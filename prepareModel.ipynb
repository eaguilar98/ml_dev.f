# %% [markdown]
# ### Preparando el Modelo

# %% [markdown]
# Librerias

# %%
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import seaborn           as sns

import requests
import pandas as pd
import dns
from urllib.request import urlopen
import json

pd.options.display.max_columns=100

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

import time

# %% [markdown]
# Load data

# %%
mi_data='inegi_data_jiros_raw.csv'
df=pd.read_csv(mi_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5468854 entries, 0 to 5468853
# Columns: 186 entries, Unnamed: 0 to deportistas
# dtypes: float64(2), int64(173), object(11)
# memory usage: 7.6+ GB

# %%
#Inspeccion visual
df.sample(5)
# Out:
#          Unnamed: 0                          clee       id  \
# 4080401     4126391  23004811499000461000000000U2  3637079
# 2373321     2402116  32017332320001851000000000U2  8483615
# 4397393     4448005  30025811219000021000000000U2  7658945
# 2132902     2157070  11017467111000091000000000U1  1333386
# 442144       446749  03009813230000091000000000U7  7815626
#
#                                     nombre  \
# 4080401                    sastreria lopez
# 2373321        herreria la sagrada familia
# 4397393  taller de reparacion de celulares
# 2132902              ferreteria sin nombre
# 442144   asociacion de hoteleros de loreto
#
#                                            clase_actividad             calle  \
# 4080401  reparación y mantenimiento de otros artículos ...  francisco valdez
# 2373321               fabricación de productos de herrería         deportiva
# 4397393  reparación y mantenimiento de otro equipo elec...      constitucion
# ...

# %%
columnas=df.columns

# %%
columnas.to_frame().to_csv('columnas.csv')

# %%
_columnas={
'"captación,"':'captacion',
'hojalatería':'hojalateria',
'edición':'edicion',
'elaboración':'elaboracion',
'"cafeterías,"':'cafes',
'agencias':'agencias',
'impresión':'impresion',
'fabricación':'fabricacion',
'reparación':'reparacion',
'transmisión':'transmision',
'lavanderías':'lavanderias',
'edificación':'edificacion',
'colocación':'colocacion',
'administración':'administracion',
'purificación':'purificacion',
"bares,":'bares',
"asociaciones,":'asociaciones',
'impartición':'imparticion',
'panificación':'panaderias',
'guarderías':'guarderias',
"agentes,":'agentes',
'grabación':'grabacion',
'diseño':'diseno',
'producción':'produccion',
'compañías':'companias',
'intermediación':'intermediacion',
"confección,":'confeccion',
'cerrajerías':'cerrajerias',
'regulación':'regulacion',
'instalación':'instalacion',
'notarías':'notarias',
'joyería':'joyeria',
'conservación':'conservacion',
'construcción':'construccion',
"cabañas,":'cabanas',
'clínicas':'clinicas',
'supervisión':'supervision',
'recolección':'recoleccion',
'realización':'realizacion',
'preparación':'preparacion',
"artistas,":'artistas',
'distribución':'distribucion',
'alineación':'alineacion',
'orfebrería':'orfebreria',
'deshidratación':'deshidratacion',
'asesoría':'asesoria',
'generación':'generacion',
'montepíos':'montepios',
'rectificación':'rectificacion',
'tapicería':'tapiceria',
'extracción':'extraccion',
'baños':'banos',
'congelación':'congelacion',
'organización':'organizacion',
'perforación':'perforacion',
'órganos':'organos',
'exhibición':'exhibicion',
'comercialización':'comercio',
'"grutas,"':'grutas',
'obtención':'obtencion',
'división':'division',
'metalistería':'metalisteria',
'fundición':'fundicion',
'revitalización':'revitalizacion',
'acuñación':'acunacion',
'refinación':'refinacion'
}

# %%
_rename={
    'minería':'mineria',
    'grutas,':'grutas',
    'recuperación':'recuperacion'
}

# %%
df.rename(columns=_rename,inplace=True)

# %%
df.info(verbose=True, null_counts=True,max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5468854 entries, 0 to 5468853
# Data columns (total 185 columns):
#  #    Column            Non-Null Count    Dtype
# ---   ------            --------------    -----
#  0    clee              5468854 non-null  object
#  1    id                5468854 non-null  int64
#  2    nombre            5468854 non-null  object
#  3    clase_actividad   5468854 non-null  object
#  4    calle             5468743 non-null  object
#  5    ciudad            5468854 non-null  object
#  6    municipio         5468854 non-null  object
#  7    entidad           5468854 non-null  object
#  8    colonia           5468724 non-null  object
#  9    cp                5468854 non-null  int64
#  10   tipo              5468854 non-null  object
#  11   longitud          5468854 non-null  float64
#  12   latitud           5468854 non-null  float64
#  13   jiro              5468854 non-null  object
#  14   explicativo       5449457 non-null  object
# ...

# %%
corr=df.corr()

# %%
corr.to_csv('mi_correlacion.csv')

# %% [markdown]
# ### Agrupando la informacion para el modelo

# %%
agrupado_df=df.groupby(
        [
            'cp',
            'ciudad',
            'municipio',
            'entidad'
        ]
    )\
        [
            'acabado',
            'actividades',
            'acunacion',
            'administracion',
            'agencias',
            'agentes',
            'agentes',
            'agrupaciones',
            'alineacion',
            'almacenamiento',
            'almacenes',
            'alquiler',
            'artistas',
            'aserraderos',
            'aserrado',
            'asesoria',
            'asilos',
            'asociaciones',
            'asociaciones',
            'autotransporte',
            'banca',
            'banos',
            'bares',
            'beneficio',
            'bibliotecas',
            'billares',
            'boliches',
            'bolsa',
            'bufetes',
            'cabanas',
            'cafe',
            'cajas',
            'camaronicultura',
            'campamentos',
            'campos',
            'cantantes',
            'capacitacion',
            'casas',
            'casinos',
            'centros',
            'cerrajerias',
            'clinicas',
            'clubes',
            'colocacion',
            'comercio',
            'comercio',           
            'companias',
            'complejos',
            'confeccion',
            'confeccion',
            'congelacion',
            'conservacion',
            'construccion',
            'consultorios',
            'contadores',
            'corporativos',
            'corte',            
            'curtido',
            'de_sistemas',
            'departamentos',
            'deportistas',
            'deshidratacion',
            'despachos',
            'despepite',
            'diseno',
            'distribucion',
            'division',
            'edicion',
            'edificacion',
            'editoras',
            'elaboracion',
            'equipos',
            'escuelas',
            'estacionamientos',
            'exhibicion',
            'extraccion',
            'fabricacion',
            'farmacias',
            'fondos',
            'fundicion',
            'generacion',
            'godinez',
            'grabacion',
            'grupos',
            'grutas',
            'guarderias',
            'hojalateria',
            'hospitales',
            'hoteles',            
            'imparticion',
            'impresion',
            'industria',
            'industrias',
            'inmobiliarias',
            'instalacion',
            'instalaciones',
            'intermediacion',
            'jardines',
            'joyeria',
            'laboratorios',                      
            'lavado',
            'lavanderias',            
            'manejo',
            'maquinado',
            'marinas',
            'matanza',
            'metalisteria',
            'mineria',
            'moldeo',
            'montaje',
            'montepios',
            'moteles',
            'museos',
            'notarias',
            'obtencion',
            'operadores',
            'orfanatos',
            'orfebreria',
            'organismos',
            'organizacion',
            'organizadores',
            'organos',            
            'panaderias',
            'parques',
            'pensiones',
            'perforacion',
            'pesca',
            'piscicultura',
            'preparacion',
            'procesamiento',
            'produccion',
            'productoras',
            'promotores',
            'purificacion',
            'realizacion',
            'recoleccion',
            'rectificacion',
            'recubrimientos',
            'recuperacion',
            'refinacion',
            'refugios',
            'regulacion',
            'relaciones',
            'reparacion',
            'residencias',
            'restaurantes',
            'revitalizacion',
            'salones',
            'sanitarios',
            'servicios',
            'sitios',
            'sociedades',
            'suministro',
            'supervision',            
            'tapiceria',
            'tenedoras',
            'trabajadores',
            'trabajos',
            'transmision',
            'transporte',
            'tratamiento',
            'uniones',
            'venta',
            'comida',
            'comida_corrida',
            'tacos_tortas'
            ].sum()

# %%
agrupado_df.reset_index(inplace=True)

# %%
agrupado_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56376 entries, 0 to 56375
# Columns: 178 entries, cp to tacos_tortas
# dtypes: int64(175), object(3)
# memory usage: 76.6+ MB

# %%
agrupado_df.to_csv('datemodel.csv')

# %%
CP_agrupado_df=df.groupby(
        [
            'cp'            
        ]
    )\
        [
            'acabado',
            'actividades',
            'acunacion',
            'administracion',
            'agencias',
            'agentes',           
            'agrupaciones',
            'alineacion',
            'almacenamiento',
            'almacenes',
            'alquiler',
            'artistas',
            'aserraderos',
            'aserrado',
            'asesoria',
            'asilos',
            'asociaciones',
            'asociaciones',
            'autotransporte',
            'banca',
            'banos',
            'bares',
            'beneficio',
            'bibliotecas',
            'billares',
            'boliches',
            'bolsa',
            'bufetes',
            'cabanas',
            'cafe',
            'cajas',
            'camaronicultura',
            'campamentos',
            'campos',
            'cantantes',
            'capacitacion',
            'casas',
            'casinos',
            'centros',
            'cerrajerias',
            'clinicas',
            'clubes',
            'colocacion',
            'comercio',
            'comercio',           
            'companias',
            'complejos',
            'confeccion',
            'confeccion',
            'congelacion',
            'conservacion',
            'construccion',
            'consultorios',
            'contadores',
            'corporativos',
            'corte',            
            'curtido',
            'de_sistemas',
            'departamentos',
            'deportistas',
            'deshidratacion',
            'despachos',
            'despepite',
            'diseno',
            'distribucion',
            'division',
            'edicion',
            'edificacion',
            'editoras',
            'elaboracion',
            'equipos',
            'escuelas',
            'estacionamientos',
            'exhibicion',
            'extraccion',
            'fabricacion',
            'farmacias',
            'fondos',
            'fundicion',
            'generacion',
            '',
            'grabacion',
            'grupos',
            'grutas',
            'guarderias',
            'hojalateria',
            'hospitales',
            'hoteles',            
            'imparticion',
            'impresion',
            'industria',
            'industrias',
            'inmobiliarias',
            'instalacion',
            'instalaciones',
            'intermediacion',
            'jardines',
            'joyeria',
            'laboratorios',                      
            'lavado',
            'lavanderias',            
            'manejo',
            'maquinado',
            'marinas',
            'matanza',
            'metalisteria',
            'mineria',
            'moldeo',
            'montaje',
            'montepios',
            'moteles',
            'museos',
            'notarias',
            'obtencion',
            'operadores',
            'orfanatos',
            'orfebreria',
            'organismos',
            'organizacion',
            'organizadores',
            'organos',            
            'panaderias',
            'parques',
            'pensiones',
            'perforacion',
            'pesca',
            'piscicultura',
            'preparacion',
            'procesamiento',
            'produccion',
            'productoras',
            'promotores',
            'purificacion',
            'realizacion',
            'recoleccion',
            'rectificacion',
            'recubrimientos',
            'recuperacion',
            'refinacion',
            'refugios',
            'regulacion',
            'relaciones',
            'reparacion',
            'residencias',
            'restaurantes',
            'revitalizacion',
            'salones',
            'sanitarios',
            'servicios',
            'sitios',
            'sociedades',
            'suministro',
            'supervision',            
            'tapiceria',
            'tenedoras',
            'trabajadores',
            'trabajos',
            'transmision',
            'transporte',
            'tratamiento',
            'uniones',
            'venta',
            'comida',
            'comida_corrida',
            'tacos_tortas'
            ].sum()

# %%
CP_agrupado_df.to_csv('datemodel_cp.csv')
